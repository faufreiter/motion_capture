# %% [markdown]
# # Motion capture

# %%
import pandas as pd

# %%
data_P1_angle_right = pd.read_csv('./data/training_P1_Angle_right.tsv', sep='\t')
#first few rows
print(data_P1_angle_right.head())
# Out:
#        NO_OF_FRAMES                  6585
# 0  NO_OF_DATA_TYPES                     1
# 1         FREQUENCY                   100
# 2        TIME_STAMP  2023-11-24, 16:15:56
# 3     DATA_INCLUDED                 Angle
# 4        DATA_TYPES                 Angle

# %% [markdown]
# ## Data analysis
#
# **data per person**:
# * right arm: magnitude, angle (frame info) --> name: **training_P#_ram_final**
# * left arm: magnitude, angle (frame info) --> name: **training_P#_lam_final**
# * right elbow: distance traveled (frame info) --> name: **training_P#_Rdist_traveled_final**
# * left elbow: distance traveled (frame info) --> name: **training_P#__Ldist_traveled_final**

# %%
data_P1_angle_right_mag1 = pd.read_csv('./data/training_P1_Angle_mag_only.csv')
#first few rows
print(data_P1_angle_right_mag1.head())

#Documents/GitHub/motion_capture/data/training_P1_Angle_mag_only.csv
# Out:
#     Angle
# 0  161865
# 1  161861
# 2  161870
# 3  160771
# 4  160772

# %%
average = data_P1_angle_right_mag1.loc[14:1999,'Angle'].mean()

print("Average:", average)
# Out:
# Average: 121748.472306143

# %%
average_new = average/ 1000
average_new
# Out:
# 121.748472306143

# %%
num_rows = len(data_P1_angle_right_mag1)
num_rows
# Out:
# 6585

# %%
data_training_P1_ram_final = pd.read_csv('./data/P1/training_P1_ram_final.csv')
#first few rows
print(data_training_P1_ram_final.head())

#Documents/GitHub/motion_capture/data/training_P1_Angle_mag_only.csv
#Documents/GitHub/motion_capture/data/P1/training_P1_ram_final.csv
# Out:
#        NO_OF_FRAMES                  6585
# 0  NO_OF_DATA_TYPES                     1
# 1         FREQUENCY                   100
# 2        TIME_STAMP  2023-11-29, 18:25:14
# 3     DATA_INCLUDED                 Angle
# 4        DATA_TYPES          P1_ram_final

# %%
average_training_P1_ram_final = data_training_P1_ram_final.loc[9:1999,'NO_OF_FRAMES'].mean()

print("Average:", average)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1622, in _ensure_numeric(x)
#    1621 try:
# -> 1622     x = float(x)
#    1623 except (TypeError, ValueError):
#    1624     # e.g. "1+1j" or "foo"
#
# ...
